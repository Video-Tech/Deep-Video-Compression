# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
f = 'logs/report_foot_0001.log'
data = np.loadtxt(f)

# %%
for i in data:
    print i[4]/i[5]
# Out:
# 1400.17464789
# 3327.4954955
# 3206.556
# 4471.13286713
# 7708.18818819
# 7064.792
# 4889.048
# 7208.96
# 5147.004
# 3001.41458541
# 7628.23623624
# 7542.784
# 6080.432
# 4884.54745255
# 3450.88
# 7650.78678679
# 5283.544
# 5594.228
# 4573.06693307
# 3653.18918919
# 4928.888
# 4766.216
# 4389.088
# 3561.192
# 3806.976
# 5790.316
# 7356.26773227
# 6273.48948949
# 4855.54445554
# 3870.72
# 6367.45545546
# 6934.528
# 6161.61038961
# 3687.58
# 1570.33833834
# 4399.104
# 3792.08791209
# 2833.16516517
# 3099.532
# 5122.05794206
# 4935.66366366
# 5893.816
# 5960.804
# 4896.36
# 2519.04
# 7122.944
# 7292.928
# 7206.912
# 7180.68331668
# 6144.23623624
# 7137.66
# 6859.636
# 5288.54
# 5618.23776224
# 6115.25125125
# 6881.54
# 6972.22
# 7827.524
# 7338.46
# 7737.87012987
# 8357.86986987
# 9218.08
# 7646.284
# 7161.856
# 2816.0
# 3256.32
# 6782.976
# 7434.24
# 6914.048
# 3379.2
# 5691.392
# 6078.464
# 7158.79320679
# 7355.57957958
# 3940.50749251
# 5550.08
# 7523.68368368
# 8028.32367632
# ...

# %%
files = glob.glob('logs/*.log')
for f in files:
    data = np.loadtxt(f)
    d = []
    for i in data:
        d.append(i[4]*8/i[5])
    plt.plot(d)
    plt.show()
